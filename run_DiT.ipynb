# %% [markdown]
# # Scalable Diffusion Models with Transformer (DiT)
#
# This notebook samples from pre-trained DiT models. DiTs are class-conditional latent diffusion models trained on ImageNet that use transformers in place of U-Nets as the DDPM backbone. DiT outperforms all prior diffusion models on the ImageNet benchmarks.
#
# [Project Page](https://www.wpeebles.com/DiT) | [HuggingFace Space](https://huggingface.co/spaces/wpeebles/DiT) | [Paper](http://arxiv.org/abs/2212.09748) | [GitHub](github.com/facebookresearch/DiT)

# %% [markdown]
# # 1. Setup
#
# We recommend using GPUs (Runtime > Change runtime type > Hardware accelerator > GPU). Run this cell to clone the DiT GitHub repo and setup PyTorch. You only have to run this once.

# %%
# !git clone https://github.com/facebookresearch/DiT.git
import DiT, os
os.chdir('DiT')
os.environ['PYTHONPATH'] = '/env/python:/content/DiT'
# !pip install diffusers timm --upgrade
# DiT imports:
import torch
from torchvision.utils import save_image
from diffusion import create_diffusion
from diffusers.models import AutoencoderKL
from download import find_model
from models import DiT_XL_2
from PIL import Image
from IPython.display import display
torch.set_grad_enabled(False)
device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cpu":
    print("GPU not found. Using CPU instead.")
# Out:
# Cloning into 'DiT'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 102 (delta 57), reused 33 (delta 33), pack-reused 20 (from 1)
# Receiving objects: 100% (102/102), 6.36 MiB | 24.22 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.32.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.15)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.6.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers) (3.17.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers) (11.1.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.20.1+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (24.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.23.2->diffusers) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 82.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 772.7 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# GPU not found. Using CPU instead.

# %% [markdown]
# # Download DiT-XL/2 Models
#
# You can choose between a 512x512 model and a 256x256 model. You can swap-out the LDM VAE, too.

# %%
image_size = "512" #@param [256, 512]
vae_model = "stabilityai/sd-vae-ft-mse" #@param ["stabilityai/sd-vae-ft-mse", "stabilityai/sd-vae-ft-ema"]
latent_size = int(image_size) // 8
# Load model:
model = DiT_XL_2(input_size=latent_size).to(device)
state_dict = find_model(f"DiT-XL-2-{image_size}x{image_size}.pt")
model.load_state_dict(state_dict)
model.eval() # important!
#vae = AutoencoderKL.from_pretrained(vae_model).to(device)
###########################################################################################
# !pip install torchinfo

import torch
from torchinfo import summary
from collections import defaultdict

# 定义输入参数
latent_channels = 4  # VAE输出的潜在空间通道数
input_shape = (latent_channels, latent_size, latent_size)  # 自动计算潜在空间尺寸

def dit_parameter_stat(model):
    """ DiT专用参数统计函数 """
    # 核心统计功能
    model_stats = summary(
        model,
        input_size=(1, *input_shape),  # Batch size=1
        col_names=["input_size", "output_size", "num_params", "kernel_size", "mult_adds"],
        verbose=0
    )

    # 自定义参数分析
    param_details = defaultdict(lambda: {"count":0, "layers":[]})
    for layer in model_stats.summary_list:
        if layer.num_params > 0:
            layer_type = layer.class_name
            param_details[layer_type]["count"] += 1
            param_details[layer_type]["layers"].append({
                "name": layer.layer_name,
                "params": layer.num_params,
                "input_shape": layer.input_size,
                "output_shape": layer.output_size
            })

    # 打印报告
    print(f"\n{' 参数统计报告 ':=^80}")
    print(f"输入尺寸: {input_shape}")
    print(f"总参数量: {model_stats.total_params:,} (约 {model_stats.total_params/1e6:.2f}M)")

    print("\n各层类型分布:")
    for layer_type, data in param_details.items():
        print(f"• {layer_type:<15} ×{data['count']:<3} → {sum(l['params'] for l in data['layers'])/1e6:.2f}M")

    print("\n详细层参数计算:")
    for layer in model_stats.summary_list:
        if layer.num_params > 0:
            params_m = layer.num_params / 1e6
            print(f"[{layer.class_name}] {layer.layer_name}")
            print(f"  Input: {layer.input_size[1:]} → Output: {layer.output_size[1:]}")
            print(f"  Parameters: {layer.num_params:,} ({params_m:.3f}M)")
            if hasattr(layer, "kernel_size") and layer.kernel_size is not None:
                print(f"  Kernel: {layer.kernel_size}")

# 执行统计
dit_parameter_stat(model)

#############################################################################################
# import torch

# def calculate_parameters(model):
#     """输出模型参数量及详细计算过程"""
#     total_params = sum(p.numel() for p in model.parameters())

#     # 初始化各组件参数统计
#     components = {
#         "Embedding Layers": 0,
#         "Transformer Blocks": 0,
#         "Final Layers": 0,
#         "Conditioning Modules": 0
#     }

#     # 详细层参数记录
#     layer_details = []

#     # 递归遍历所有模块
#     for name, module in model.named_modules():
#         params = sum(p.numel() for p in module.parameters(recurse=False))

#         # 分类统计主要组件
#         if 'x_embedder' in name or 'pos_embed' in name:
#             components["Embedding Layers"] += params
#         elif 'blocks' in name:
#             components["Transformer Blocks"] += params
#         elif 'final_layer' in name or 'output' in name:
#             components["Final Layers"] += params
#         elif 'adaLN' in name or 'mlp_t' in name:
#             components["Conditioning Modules"] += params

#         # 记录每个参数层的详细信息
#         if params > 0 and list(module.children()) == []:  # 只处理叶子节点
#             layer_info = {
#                 "name": name,
#                 "type": type(module).__name__,
#                 "params": params,
#                 "shape": []
#             }

#             # 记录具体参数形状
#             for p_name, param in module.named_parameters(recurse=False):
#                 layer_info["shape"].append(f"{p_name}: {tuple(param.shape)}")

#             layer_details.append(layer_info)

#     # 打印统计结果
#     print(f"\n{' 模型参数量分析 ':=^80}")
#     print(f"总参数量: {total_params:,} (约 {total_params/1e6:.1f}M)")
#     print("\n主要组件参数分布:")
#     for k, v in components.items():
#         print(f"• {k:<20} {v/1e6:>6.2f}M ({v/total_params:.1%})")

#     # 打印详细参数计算过程
#     print("\n详细层参数计算:")
#     for detail in layer_details:
#         print(f"\n▌ 层名称: {detail['name']}")
#         print(f"  类型: {detail['type']}")
#         print(f"  参数量: {detail['params']:,}")
#         print("  参数形状:")
#         for shape_info in detail['shape']:
#             print(f"    └ {shape_info}")

# # 执行计算
# calculate_parameters(model)
# Out:
# =================================== 模型参数量分析 ====================================
# 总参数量: 676,014,368 (约 676.0M)
#
# 主要组件参数分布:
# • Embedding Layers       0.02M (0.0%)
# • Transformer Blocks   669.34M (99.0%)
# • Final Layers           2.69M (0.4%)
# • Conditioning Modules   0.00M (0.0%)
#
# 详细层参数计算:
#
# ▌ 层名称: x_embedder.proj
#   类型: Conv2d
#   参数量: 19,584
#   参数形状:
#     └ weight: (1152, 4, 2, 2)
#     └ bias: (1152,)
#
# ▌ 层名称: t_embedder.mlp.0
#   类型: Linear
#   参数量: 296,064
#   参数形状:
#     └ weight: (1152, 256)
#     └ bias: (1152,)
#
# ▌ 层名称: t_embedder.mlp.2
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: y_embedder.embedding_table
#   类型: Embedding
#   参数量: 1,153,152
#   参数形状:
#     └ weight: (1001, 1152)
#
# ▌ 层名称: blocks.0.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.0.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.0.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.0.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.0.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.1.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.1.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.1.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.1.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.1.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.2.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.2.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.2.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.2.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.2.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.3.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.3.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.3.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.3.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.3.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.4.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.4.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.4.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.4.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.4.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.5.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.5.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.5.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.5.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.5.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.6.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.6.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.6.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.6.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.6.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.7.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.7.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.7.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.7.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.7.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.8.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.8.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.8.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.8.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.8.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.9.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.9.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.9.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.9.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.9.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.10.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.10.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.10.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.10.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.10.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.11.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.11.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.11.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.11.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.11.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.12.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.12.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.12.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.12.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.12.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.13.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.13.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.13.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.13.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.13.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.14.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.14.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.14.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.14.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.14.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.15.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.15.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.15.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.15.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.15.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.16.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.16.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.16.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.16.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.16.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.17.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.17.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.17.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.17.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.17.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.18.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.18.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.18.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.18.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.18.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.19.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.19.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.19.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.19.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.19.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.20.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.20.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.20.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.20.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.20.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.21.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.21.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.21.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.21.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.21.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.22.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.22.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.22.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.22.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.22.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.23.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.23.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.23.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.23.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.23.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.24.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.24.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.24.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.24.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.24.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.25.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.25.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.25.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.25.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.25.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.26.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.26.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.26.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.26.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.26.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: blocks.27.attn.qkv
#   类型: Linear
#   参数量: 3,984,768
#   参数形状:
#     └ weight: (3456, 1152)
#     └ bias: (3456,)
#
# ▌ 层名称: blocks.27.attn.proj
#   类型: Linear
#   参数量: 1,328,256
#   参数形状:
#     └ weight: (1152, 1152)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.27.mlp.fc1
#   类型: Linear
#   参数量: 5,313,024
#   参数形状:
#     └ weight: (4608, 1152)
#     └ bias: (4608,)
#
# ▌ 层名称: blocks.27.mlp.fc2
#   类型: Linear
#   参数量: 5,309,568
#   参数形状:
#     └ weight: (1152, 4608)
#     └ bias: (1152,)
#
# ▌ 层名称: blocks.27.adaLN_modulation.1
#   类型: Linear
#   参数量: 7,969,536
#   参数形状:
#     └ weight: (6912, 1152)
#     └ bias: (6912,)
#
# ▌ 层名称: final_layer.linear
#   类型: Linear
#   参数量: 36,896
#   参数形状:
#     └ weight: (32, 1152)
#     └ bias: (32,)
#
# ▌ 层名称: final_layer.adaLN_modulation.1
#   类型: Linear
#   参数量: 2,656,512
#   参数形状:
#     └ weight: (2304, 1152)
#     └ bias: (2304,)

# %% [markdown]
# # 2. Sample from Pre-trained DiT Models
#
# You can customize several sampling options. For the full list of ImageNet classes, [check out this](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from torchstat import stat
# Set user inputs:
seed = 0 #@param {type:"number"}
torch.manual_seed(seed)
num_sampling_steps = 250 #@param {type:"slider", min:0, max:1000, step:1}
cfg_scale = 4 #@param {type:"slider", min:1, max:10, step:0.1}
class_labels = 207, 360, 387, 974, 88, 979, 417, 279 #@param {type:"raw"}
samples_per_row = 4 #@param {type:"number"}

# Create diffusion object:
diffusion = create_diffusion(str(num_sampling_steps))

# Create sampling noise:
n = len(class_labels)
z = torch.randn(n, 4, latent_size, latent_size, device=device)
y = torch.tensor(class_labels, device=device)

# Setup classifier-free guidance:
z = torch.cat([z, z], 0)
y_null = torch.tensor([1000] * n, device=device)
y = torch.cat([y, y_null], 0)
model_kwargs = dict(y=y, cfg_scale=cfg_scale)

# Sample images:
samples = diffusion.p_sample_loop(
    model.forward_with_cfg, z.shape, z, clip_denoised=False,
    model_kwargs=model_kwargs, progress=True, device=device
)
samples, _ = samples.chunk(2, dim=0)  # Remove null class samples
samples = vae.decode(samples / 0.18215).sample

# Save and display images:
save_image(samples, "sample.png", nrow=int(samples_per_row),
           normalize=True, value_range=(-1, 1))
samples = Image.open("sample.png")
display(samples)
